# %%
from google.colab import drive

# %%
ROOT='/content/drive'
drive.mount(ROOT)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
HOME= ROOT + '/My Drive/Colab Notebooks'
HOME
# Out:
# '/content/drive/My Drive/Colab Notebooks'

# %%
# !mkdir -p '{HOME}'

# %%
cd{HOME}
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks'

# %%
ls
# Out:
# day4meta.ipynb  dw_matrix/

# %%
GITHUB_TOKEN = 'aab0a03458f5a539e1a5eaf9a7127a1f1a22c641'

GITHUB_URL = 'https://{}@github.com/Ondraszek13/dw_matrix.git'.format(GITHUB_TOKEN)
GITHUB_URL
# Out:
# 'https://aab0a03458f5a539e1a5eaf9a7127a1f1a22c641@github.com/Ondraszek13/dw_matrix.git'

# %%
# !git clone {GITHUB_URL}
# Out:
# fatal: destination path 'dw_matrix' already exists and is not an empty directory.

# %%
ls
# Out:
# day4meta.ipynb  dw_matrix/

# %%
cd dw_matrix/
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix

# %%
ls
# Out:
# ColabDriveGithub.ipynb  Hello_Github.ipynb  matrix_one/
# data/                   LICENSE             README.md

# %%
# !git add Hello_Github.ipynb

# %%
# !git commit -m "add my first notebook - hello github"
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@b27719d3b91c.(none)')

# %%
# !git config --global user.email "a.okolowicz.seweryn@gmail.com"
# !git config --global user.name "Ola O-S"

# %%
# !git commit -m "add my first notebook - hello github"
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 5 commits.
#   (use "git push" to publish your local commits)
#
# Changes not staged for commit:
# 	deleted:    day4.ipynb
# 	modified:   matrix_one/day3.ipynb
# 	modified:   matrix_one/day4.ipynb
#
# Untracked files:
# 	ColabDriveGithub.ipynb
#
# no changes added to commit

# %%
# !git push -u origin master
# Out:
# fatal: could not read Password for 'https://fd07627239b239fff6bc38266244d5086567702d@github.com': No such device or address
